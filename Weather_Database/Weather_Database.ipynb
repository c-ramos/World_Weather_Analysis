# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Starting URL for weather map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Current Description": city_description})

   # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

len(city_data)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | sao felix do xingu
# Processing Record 3 of Set 1 | brae
# Processing Record 4 of Set 1 | victoria
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | denpasar
# Processing Record 7 of Set 1 | kalimnos
# City not found. Skipping...
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 1 | belen de umbria
# Processing Record 11 of Set 1 | tutoia
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | dingle
# Processing Record 14 of Set 1 | stavern
# Processing Record 15 of Set 1 | ust-nera
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | upernavik
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | carutapera
# Processing Record 23 of Set 1 | kahului
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | santa fe
# Processing Record 26 of Set 1 | cayenne
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | caravelas
# Processing Record 31 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 1 | fortuna
# Processing Record 33 of Set 1 | hilo
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | tecpan
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | bauchi
# Processing Record 39 of Set 1 | hamilton
# Processing Record 40 of Set 1 | nantucket
# Processing Record 41 of Set 1 | east london
# Processing Record 42 of Set 1 | iqaluit
# Processing Record 43 of Set 1 | clyde river
# Processing Record 44 of Set 1 | satipo
# Processing Record 45 of Set 1 | katsuura
# Processing Record 46 of Set 1 | sorland
# Processing Record 47 of Set 1 | geraldton
# Processing Record 48 of Set 1 | lorengau
# Processing Record 49 of Set 1 | mitsamiouli
# Processing Record 50 of Set 1 | san rafael
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | yar-sale
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | malanje
# Processing Record 5 of Set 2 | touros
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | faanui
# Processing Record 8 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 2 | rosetta
# Processing Record 10 of Set 2 | nisia floresta
# Processing Record 11 of Set 2 | kurikka
# Processing Record 12 of Set 2 | hasaki
# Processing Record 13 of Set 2 | bethel
# Processing Record 14 of Set 2 | srednekolymsk
# Processing Record 15 of Set 2 | boma
# Processing Record 16 of Set 2 | kozulka
# Processing Record 17 of Set 2 | camacha
# Processing Record 18 of Set 2 | garden city
# Processing Record 19 of Set 2 | honiara
# Processing Record 20 of Set 2 | den helder
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | provideniya
# Processing Record 23 of Set 2 | rypefjord
# Processing Record 24 of Set 2 | alice springs
# Processing Record 25 of Set 2 | esmeralda
# Processing Record 26 of Set 2 | berbera
# Processing Record 27 of Set 2 | arrecife
# Processing Record 28 of Set 2 | coihaique
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 2 | klaksvik
# Processing Record 32 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 2 | kavaratti
# Processing Record 34 of Set 2 | qaanaaq
# Processing Record 35 of Set 2 | wattegama
# Processing Record 36 of Set 2 | vila do maio
# Processing Record 37 of Set 2 | kaitangata
# Processing Record 38 of Set 2 | sept-iles
# Processing Record 39 of Set 2 | lagoa
# Processing Record 40 of Set 2 | isangel
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | itamaraca
# Processing Record 43 of Set 2 | port blair
# Processing Record 44 of Set 2 | chokurdakh
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | aykino
# Processing Record 47 of Set 2 | tabou
# Processing Record 48 of Set 2 | umba
# Processing Record 49 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 2 | lebu
# Processing Record 1 of Set 3 | cherskiy
# Processing Record 2 of Set 3 | ippy
# Processing Record 3 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 3 | atasu
# Processing Record 5 of Set 3 | half moon bay
# Processing Record 6 of Set 3 | kodiak
# Processing Record 7 of Set 3 | bambous virieux
# Processing Record 8 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 10 of Set 3 | evensk
# Processing Record 11 of Set 3 | gravdal
# Processing Record 12 of Set 3 | contai
# Processing Record 13 of Set 3 | omboue
# Processing Record 14 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 3 | verkhnyaya toyma
# Processing Record 16 of Set 3 | soyo
# Processing Record 17 of Set 3 | aksu
# Processing Record 18 of Set 3 | moss point
# Processing Record 19 of Set 3 | torbay
# Processing Record 20 of Set 3 | houma
# Processing Record 21 of Set 3 | saint-georges
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | tasiilaq
# Processing Record 24 of Set 3 | oil city
# Processing Record 25 of Set 3 | aklavik
# Processing Record 26 of Set 3 | nemuro
# Processing Record 27 of Set 3 | pahrump
# Processing Record 28 of Set 3 | bolshiye uki
# City not found. Skipping...
# Processing Record 29 of Set 3 | greenfield
# Processing Record 30 of Set 3 | paamiut
# Processing Record 31 of Set 3 | aurdal
# Processing Record 32 of Set 3 | cape town
# Processing Record 33 of Set 3 | bosaso
# Processing Record 34 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 36 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 37 of Set 3 | almora
# Processing Record 38 of Set 3 | abnub
# Processing Record 39 of Set 3 | arari
# Processing Record 40 of Set 3 | hithadhoo
# Processing Record 41 of Set 3 | sisimiut
# Processing Record 42 of Set 3 | pisco
# Processing Record 43 of Set 3 | abu samrah
# Processing Record 44 of Set 3 | bourbonnais
# Processing Record 45 of Set 3 | barrow
# Processing Record 46 of Set 3 | ahipara
# Processing Record 47 of Set 3 | hobart
# Processing Record 48 of Set 3 | los llanos de aridane
# Processing Record 49 of Set 3 | kulhudhuffushi
# Processing Record 50 of Set 3 | bowen
# Processing Record 1 of Set 4 | mizdah
# Processing Record 2 of Set 4 | igarka
# Processing Record 3 of Set 4 | castro
# Processing Record 4 of Set 4 | kyaikkami
# Processing Record 5 of Set 4 | esperance
# Processing Record 6 of Set 4 | bud
# Processing Record 7 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 4 | genhe
# Processing Record 9 of Set 4 | constitucion
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | stornoway
# Processing Record 12 of Set 4 | santo amaro da imperatriz
# Processing Record 13 of Set 4 | bani walid
# Processing Record 14 of Set 4 | turayf
# Processing Record 15 of Set 4 | markala
# Processing Record 16 of Set 4 | hermanus
# Processing Record 17 of Set 4 | praia da vitoria
# Processing Record 18 of Set 4 | leopold
# Processing Record 19 of Set 4 | thompson
# Processing Record 20 of Set 4 | zhigalovo
# Processing Record 21 of Set 4 | deputatskiy
# Processing Record 22 of Set 4 | calvia
# Processing Record 23 of Set 4 | itupiranga
# Processing Record 24 of Set 4 | itaituba
# Processing Record 25 of Set 4 | college
# Processing Record 26 of Set 4 | khani
# Processing Record 27 of Set 4 | teya
# Processing Record 28 of Set 4 | timbiqui
# Processing Record 29 of Set 4 | bluff
# Processing Record 30 of Set 4 | newport
# Processing Record 31 of Set 4 | ribeira grande
# Processing Record 32 of Set 4 | cockburn town
# Processing Record 33 of Set 4 | buin
# Processing Record 34 of Set 4 | san policarpo
# Processing Record 35 of Set 4 | hatillo
# Processing Record 36 of Set 4 | karratha
# Processing Record 37 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 38 of Set 4 | tambilil
# Processing Record 39 of Set 4 | severo-kurilsk
# Processing Record 40 of Set 4 | cabo san lucas
# Processing Record 41 of Set 4 | ponta do sol
# Processing Record 42 of Set 4 | saint anthony
# Processing Record 43 of Set 4 | jalu
# Processing Record 44 of Set 4 | liku
# Processing Record 45 of Set 4 | saint-philippe
# Processing Record 46 of Set 4 | santa maria
# Processing Record 47 of Set 4 | potiskum
# Processing Record 48 of Set 4 | port hardy
# Processing Record 49 of Set 4 | riyadh
# Processing Record 50 of Set 4 | vinh
# Processing Record 1 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 2 of Set 5 | ilulissat
# Processing Record 3 of Set 5 | san cristobal
# Processing Record 4 of Set 5 | yakeshi
# Processing Record 5 of Set 5 | port alberni
# Processing Record 6 of Set 5 | hvammstangi
# City not found. Skipping...
# Processing Record 7 of Set 5 | hami
# Processing Record 8 of Set 5 | taoudenni
# Processing Record 9 of Set 5 | naze
# Processing Record 10 of Set 5 | guayaquil
# Processing Record 11 of Set 5 | arraial do cabo
# Processing Record 12 of Set 5 | montbrison
# Processing Record 13 of Set 5 | marystown
# Processing Record 14 of Set 5 | sakakah
# Processing Record 15 of Set 5 | lavrentiya
# Processing Record 16 of Set 5 | ikalamavony
# Processing Record 17 of Set 5 | tateyama
# Processing Record 18 of Set 5 | sao gabriel da cachoeira
# Processing Record 19 of Set 5 | caxito
# Processing Record 20 of Set 5 | westport
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | roswell
# Processing Record 23 of Set 5 | maine-soroa
# Processing Record 24 of Set 5 | san quintin
# Processing Record 25 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 5 | the valley
# Processing Record 27 of Set 5 | fort nelson
# Processing Record 28 of Set 5 | koungou
# Processing Record 29 of Set 5 | port elizabeth
# Processing Record 30 of Set 5 | sechura
# Processing Record 31 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 5 | boyolangu
# Processing Record 33 of Set 5 | pendleton
# Processing Record 34 of Set 5 | redencao
# Processing Record 35 of Set 5 | baykit
# Processing Record 36 of Set 5 | calama
# Processing Record 37 of Set 5 | axim
# Processing Record 38 of Set 5 | pevek
# Processing Record 39 of Set 5 | miles city
# Processing Record 40 of Set 5 | walvis bay
# Processing Record 41 of Set 5 | ustka
# Processing Record 42 of Set 5 | kavieng
# Processing Record 43 of Set 5 | fukuma
# Processing Record 44 of Set 5 | gao
# Processing Record 45 of Set 5 | hargeysa
# Processing Record 46 of Set 5 | jiazi
# Processing Record 47 of Set 5 | zyryanka
# Processing Record 48 of Set 5 | hofn
# Processing Record 49 of Set 5 | manakara
# Processing Record 50 of Set 5 | bacuit
# City not found. Skipping...
# Processing Record 1 of Set 6 | lazaro cardenas
# Processing Record 2 of Set 6 | itarema
# Processing Record 3 of Set 6 | nanortalik
# Processing Record 4 of Set 6 | dwarka
# Processing Record 5 of Set 6 | puerto ayacucho
# Processing Record 6 of Set 6 | severnoye
# Processing Record 7 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 6 | tuatapere
# Processing Record 9 of Set 6 | cidreira
# Processing Record 10 of Set 6 | souillac
# Processing Record 11 of Set 6 | georgiyevka
# Processing Record 12 of Set 6 | ust-kuyga
# Processing Record 13 of Set 6 | kilimatinde
# Processing Record 14 of Set 6 | tarija
# Processing Record 15 of Set 6 | ballina
# Processing Record 16 of Set 6 | bochil
# Processing Record 17 of Set 6 | morehead
# Processing Record 18 of Set 6 | cleethorpes
# Processing Record 19 of Set 6 | maldonado
# Processing Record 20 of Set 6 | markova
# Processing Record 21 of Set 6 | tiznit
# Processing Record 22 of Set 6 | contamana
# Processing Record 23 of Set 6 | khakhea
# Processing Record 24 of Set 6 | luderitz
# Processing Record 25 of Set 6 | mattawa
# Processing Record 26 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 6 | brigantine
# Processing Record 28 of Set 6 | ocean springs
# Processing Record 29 of Set 6 | ballinrobe
# Processing Record 30 of Set 6 | lagos
# Processing Record 31 of Set 6 | namibe
# Processing Record 32 of Set 6 | padang
# Processing Record 33 of Set 6 | puerto escondido
# Processing Record 34 of Set 6 | port lincoln
# Processing Record 35 of Set 6 | chuy
# Processing Record 36 of Set 6 | catalina foothills
# Processing Record 37 of Set 6 | chifeng
# Processing Record 38 of Set 6 | faya
# Processing Record 39 of Set 6 | umm kaddadah
# Processing Record 40 of Set 6 | bengkulu
# Processing Record 41 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 6 | ambilobe
# Processing Record 43 of Set 6 | bereda
# Processing Record 44 of Set 6 | codrington
# Processing Record 45 of Set 6 | kidal
# Processing Record 46 of Set 6 | necochea
# Processing Record 47 of Set 6 | nome
# Processing Record 48 of Set 6 | luwuk
# Processing Record 49 of Set 6 | mahebourg
# Processing Record 50 of Set 6 | port-gentil
# Processing Record 1 of Set 7 | atuona
# Processing Record 2 of Set 7 | hendijan
# City not found. Skipping...
# Processing Record 3 of Set 7 | ojinaga
# Processing Record 4 of Set 7 | bugulma
# Processing Record 5 of Set 7 | sorsk
# Processing Record 6 of Set 7 | maarianhamina
# Processing Record 7 of Set 7 | solwezi
# Processing Record 8 of Set 7 | dugna
# City not found. Skipping...
# Processing Record 9 of Set 7 | russell
# Processing Record 10 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 11 of Set 7 | norman wells
# Processing Record 12 of Set 7 | kabare
# Processing Record 13 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 7 | san patricio
# Processing Record 15 of Set 7 | krasnyy chikoy
# Processing Record 16 of Set 7 | andros town
# Processing Record 17 of Set 7 | worland
# Processing Record 18 of Set 7 | djenne
# Processing Record 19 of Set 7 | uniontown
# Processing Record 20 of Set 7 | brejo santo
# Processing Record 21 of Set 7 | cadillac
# Processing Record 22 of Set 7 | conceicao da barra
# Processing Record 23 of Set 7 | skjervoy
# Processing Record 24 of Set 7 | ust-maya
# Processing Record 25 of Set 7 | oranjestad
# Processing Record 26 of Set 7 | siteki
# Processing Record 27 of Set 7 | kefamenanu
# Processing Record 28 of Set 7 | kangasala
# Processing Record 29 of Set 7 | nishihara
# Processing Record 30 of Set 7 | strathpeffer
# Processing Record 31 of Set 7 | manono
# Processing Record 32 of Set 7 | brigham city
# Processing Record 33 of Set 7 | itoman
# Processing Record 34 of Set 7 | talnakh
# Processing Record 35 of Set 7 | bajil
# Processing Record 36 of Set 7 | tiksi
# Processing Record 37 of Set 7 | algiers
# Processing Record 38 of Set 7 | tubmanburg
# Processing Record 39 of Set 7 | tanjong tokong
# City not found. Skipping...
# Processing Record 40 of Set 7 | huari
# Processing Record 41 of Set 7 | moroni
# Processing Record 42 of Set 7 | saint-pierre
# Processing Record 43 of Set 7 | wladyslawowo
# Processing Record 44 of Set 7 | kristiansund
# Processing Record 45 of Set 7 | airai
# Processing Record 46 of Set 7 | stromness
# Processing Record 47 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 7 | arlit
# Processing Record 49 of Set 7 | racovita
# Processing Record 50 of Set 7 | flin flon
# Processing Record 1 of Set 8 | trairi
# Processing Record 2 of Set 8 | bandarban
# Processing Record 3 of Set 8 | malyye derbety
# Processing Record 4 of Set 8 | belmonte
# Processing Record 5 of Set 8 | balkhash
# Processing Record 6 of Set 8 | mackay
# Processing Record 7 of Set 8 | lompoc
# Processing Record 8 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 8 | muika
# City not found. Skipping...
# Processing Record 10 of Set 8 | gorontalo
# Processing Record 11 of Set 8 | rawson
# Processing Record 12 of Set 8 | buchanan
# Processing Record 13 of Set 8 | bandarbeyla
# Processing Record 14 of Set 8 | fazilka
# Processing Record 15 of Set 8 | bethanien
# Processing Record 16 of Set 8 | vila franca do campo
# Processing Record 17 of Set 8 | mahibadhoo
# Processing Record 18 of Set 8 | pacific grove
# Processing Record 19 of Set 8 | saint-augustin
# Processing Record 20 of Set 8 | paita
# Processing Record 21 of Set 8 | fairbanks
# Processing Record 22 of Set 8 | tazovskiy
# Processing Record 23 of Set 8 | copiapo
# Processing Record 24 of Set 8 | mehamn
# Processing Record 25 of Set 8 | opuwo
# Processing Record 26 of Set 8 | bemidji
# Processing Record 27 of Set 8 | lata
# Processing Record 28 of Set 8 | okhotsk
# Processing Record 29 of Set 8 | sitka
# Processing Record 30 of Set 8 | qasigiannguit
# Processing Record 31 of Set 8 | candawaga
# City not found. Skipping...
# Processing Record 32 of Set 8 | ust-uda
# Processing Record 33 of Set 8 | olafsvik
# Processing Record 34 of Set 8 | komsomolskiy
# Processing Record 35 of Set 8 | kerrabe
# City not found. Skipping...
# Processing Record 36 of Set 8 | beyneu
# Processing Record 37 of Set 8 | gat
# Processing Record 38 of Set 8 | poso
# Processing Record 39 of Set 8 | gaoual
# Processing Record 40 of Set 8 | kattivakkam
# Processing Record 41 of Set 8 | bombay
# Processing Record 42 of Set 8 | meulaboh
# Processing Record 43 of Set 8 | bilma
# Processing Record 44 of Set 8 | wanning
# Processing Record 45 of Set 8 | borogontsy
# Processing Record 46 of Set 8 | jablah
# Processing Record 47 of Set 8 | maceio
# Processing Record 48 of Set 8 | carbondale
# Processing Record 49 of Set 8 | alofi
# Processing Record 50 of Set 8 | matay
# Processing Record 1 of Set 9 | avera
# Processing Record 2 of Set 9 | nanyamba
# Processing Record 3 of Set 9 | lagoa formosa
# Processing Record 4 of Set 9 | isla vista
# Processing Record 5 of Set 9 | yenagoa
# Processing Record 6 of Set 9 | sendhwa
# Processing Record 7 of Set 9 | herat
# Processing Record 8 of Set 9 | port keats
# Processing Record 9 of Set 9 | malakal
# Processing Record 10 of Set 9 | zabrani
# Processing Record 11 of Set 9 | sao joao da barra
# Processing Record 12 of Set 9 | mount isa
# Processing Record 13 of Set 9 | jurm
# Processing Record 14 of Set 9 | te anau
# Processing Record 15 of Set 9 | tagusao
# Processing Record 16 of Set 9 | mgandu
# Processing Record 17 of Set 9 | el arenal
# Processing Record 18 of Set 9 | sao filipe
# Processing Record 19 of Set 9 | simbahan
# Processing Record 20 of Set 9 | sao domingos
# Processing Record 21 of Set 9 | cobija
# Processing Record 22 of Set 9 | jati
# Processing Record 23 of Set 9 | dhanwar
# Processing Record 24 of Set 9 | karak
# Processing Record 25 of Set 9 | coahuayana
# Processing Record 26 of Set 9 | forio
# Processing Record 27 of Set 9 | banda aceh
# Processing Record 28 of Set 9 | pangody
# Processing Record 29 of Set 9 | at-bashi
# Processing Record 30 of Set 9 | pangkalanbuun
# Processing Record 31 of Set 9 | saint george
# Processing Record 32 of Set 9 | asau
# Processing Record 33 of Set 9 | rosarito
# Processing Record 34 of Set 9 | koumac
# Processing Record 35 of Set 9 | razlog
# Processing Record 36 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 9 | morondava
# Processing Record 38 of Set 9 | makakilo city
# Processing Record 39 of Set 9 | lagunillas
# Processing Record 40 of Set 9 | saint-leu
# Processing Record 41 of Set 9 | basco
# Processing Record 42 of Set 9 | bacolod
# Processing Record 43 of Set 9 | abonnema
# Processing Record 44 of Set 9 | tyret pervaya
# Processing Record 45 of Set 9 | namatanai
# Processing Record 46 of Set 9 | cap malheureux
# Processing Record 47 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 9 | bara
# Processing Record 49 of Set 9 | popondetta
# Processing Record 50 of Set 9 | fare
# Processing Record 1 of Set 10 | tura
# Processing Record 2 of Set 10 | dunedin
# Processing Record 3 of Set 10 | nouadhibou
# Processing Record 4 of Set 10 | anadyr
# Processing Record 5 of Set 10 | mouila
# Processing Record 6 of Set 10 | cermei
# Processing Record 7 of Set 10 | pundaguitan
# Processing Record 8 of Set 10 | tabuk
# Processing Record 9 of Set 10 | narsaq
# Processing Record 10 of Set 10 | mount gambier
# Processing Record 11 of Set 10 | los alamos
# Processing Record 12 of Set 10 | atambua
# Processing Record 13 of Set 10 | xining
# Processing Record 14 of Set 10 | chuguyevka
# Processing Record 15 of Set 10 | manokwari
# Processing Record 16 of Set 10 | portland
# Processing Record 17 of Set 10 | prince rupert
# Processing Record 18 of Set 10 | oxapampa
# Processing Record 19 of Set 10 | kuchera
# Processing Record 20 of Set 10 | maltahohe
# Processing Record 21 of Set 10 | richards bay
# Processing Record 22 of Set 10 | la asuncion
# Processing Record 23 of Set 10 | baghdad
# Processing Record 24 of Set 10 | bousse
# Processing Record 25 of Set 10 | vanavara
# Processing Record 26 of Set 10 | udachnyy
# Processing Record 27 of Set 10 | marsh harbour
# Processing Record 28 of Set 10 | lalibela
# Processing Record 29 of Set 10 | namtsy
# Processing Record 30 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 31 of Set 10 | chaiyaphum
# Processing Record 32 of Set 10 | ixtapa
# Processing Record 33 of Set 10 | molina
# Processing Record 34 of Set 10 | svetlogorsk
# Processing Record 35 of Set 10 | mattru
# Processing Record 36 of Set 10 | marawi
# Processing Record 37 of Set 10 | verkhnyaya inta
# Processing Record 38 of Set 10 | champerico
# Processing Record 39 of Set 10 | suzu
# City not found. Skipping...
# Processing Record 40 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 10 | shache
# Processing Record 42 of Set 10 | poum
# Processing Record 43 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 10 | bol
# Processing Record 45 of Set 10 | kurilsk
# Processing Record 46 of Set 10 | cabedelo
# Processing Record 47 of Set 10 | roald
# Processing Record 48 of Set 10 | mananara
# Processing Record 49 of Set 10 | colmar
# Processing Record 50 of Set 10 | katherine
# Processing Record 1 of Set 11 | quatre cocos
# Processing Record 2 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 11 | vostok
# Processing Record 4 of Set 11 | haines junction
# Processing Record 5 of Set 11 | longyearbyen
# Processing Record 6 of Set 11 | verkhnevilyuysk
# Processing Record 7 of Set 11 | vanimo
# Processing Record 8 of Set 11 | hailey
# Processing Record 9 of Set 11 | shimoda
# Processing Record 10 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 11 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 12 of Set 11 | abilene
# Processing Record 13 of Set 11 | khorixas
# Processing Record 14 of Set 11 | kirkwall
# Processing Record 15 of Set 11 | berlevag
# Processing Record 16 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 11 | eyl
# Processing Record 18 of Set 11 | bathsheba
# Processing Record 19 of Set 11 | lubango
# Processing Record 20 of Set 11 | goya
# Processing Record 21 of Set 11 | burnie
# Processing Record 22 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 11 | alekseyevsk
# Processing Record 24 of Set 11 | vila velha
# Processing Record 25 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 11 | pemangkat
# Processing Record 27 of Set 11 | nanchang
# Processing Record 28 of Set 11 | goure
# Processing Record 29 of Set 11 | bonavista
# Processing Record 30 of Set 11 | grootfontein
# Processing Record 31 of Set 11 | jibuti
# Processing Record 32 of Set 11 | sioux lookout
# Processing Record 33 of Set 11 | stawell
# Processing Record 34 of Set 11 | vorontsovka
# Processing Record 35 of Set 11 | alihe
# Processing Record 36 of Set 11 | kiunga
# Processing Record 37 of Set 11 | kazerun
# Processing Record 38 of Set 11 | huilong
# Processing Record 39 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 41 of Set 11 | gorkovskoye
# City not found. Skipping...
# Processing Record 42 of Set 11 | sydney
# Processing Record 43 of Set 11 | miramar
# Processing Record 44 of Set 11 | segezha
# Processing Record 45 of Set 11 | panzhihua
# Processing Record 46 of Set 11 | gobabis
# Processing Record 47 of Set 11 | san pedro
# Processing Record 48 of Set 11 | gavere
# Processing Record 49 of Set 11 | maumere
# Processing Record 50 of Set 11 | la ciotat
# Processing Record 1 of Set 12 | comodoro rivadavia
# Processing Record 2 of Set 12 | buzmeyin
# Processing Record 3 of Set 12 | zhangye
# Processing Record 4 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 12 | nanakuli
# Processing Record 6 of Set 12 | dolores
# Processing Record 7 of Set 12 | tarnogskiy gorodok
# Processing Record 8 of Set 12 | melnikovo
# Processing Record 9 of Set 12 | mega
# Processing Record 10 of Set 12 | black river
# Processing Record 11 of Set 12 | najran
# Processing Record 12 of Set 12 | yumen
# Processing Record 13 of Set 12 | bam
# Processing Record 14 of Set 12 | bartica
# Processing Record 15 of Set 12 | harper
# Processing Record 16 of Set 12 | armidale
# Processing Record 17 of Set 12 | acapulco
# Processing Record 18 of Set 12 | asyut
# Processing Record 19 of Set 12 | minab
# Processing Record 20 of Set 12 | vao
# Processing Record 21 of Set 12 | ketchikan
# Processing Record 22 of Set 12 | havre-saint-pierre
# Processing Record 23 of Set 12 | valdez
# Processing Record 24 of Set 12 | atar
# Processing Record 25 of Set 12 | tirlyanskiy
# Processing Record 26 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 28 of Set 12 | nalut
# Processing Record 29 of Set 12 | porto novo
# Processing Record 30 of Set 12 | jackson
# Processing Record 31 of Set 12 | savonlinna
# Processing Record 32 of Set 12 | ormara
# Processing Record 33 of Set 12 | kaohsiung
# Processing Record 34 of Set 12 | casma
# Processing Record 35 of Set 12 | laguna
# Processing Record 36 of Set 12 | santa cruz
# Processing Record 37 of Set 12 | palmer
# Processing Record 38 of Set 12 | santa barbara
# Processing Record 39 of Set 12 | melville
# Processing Record 40 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 41 of Set 12 | pouembout
# Processing Record 42 of Set 12 | anloga
# Processing Record 43 of Set 12 | amahai
# Processing Record 44 of Set 12 | northam
# Processing Record 45 of Set 12 | mareeba
# Processing Record 46 of Set 12 | el fuerte
# Processing Record 47 of Set 12 | pokhara
# Processing Record 48 of Set 12 | la rioja
# Processing Record 49 of Set 12 | andijon
# Processing Record 50 of Set 12 | taltal
# Processing Record 1 of Set 13 | bubaque
# Processing Record 2 of Set 13 | simao
# Processing Record 3 of Set 13 | ostrovnoy
# Processing Record 4 of Set 13 | korla
# Processing Record 5 of Set 13 | visby
# Processing Record 6 of Set 13 | hirara
# Processing Record 7 of Set 13 | aksarka
# Processing Record 8 of Set 13 | labuhan
# Processing Record 9 of Set 13 | awbari
# Processing Record 10 of Set 13 | salvacion
# Processing Record 11 of Set 13 | bayan
# Processing Record 12 of Set 13 | buluang
# Processing Record 13 of Set 13 | puno
# Processing Record 14 of Set 13 | vikhorevka
# Processing Record 15 of Set 13 | sonoita
# Processing Record 16 of Set 13 | mutis
# Processing Record 17 of Set 13 | high rock
# Processing Record 18 of Set 13 | yulara
# Processing Record 19 of Set 13 | pangnirtung
# Processing Record 20 of Set 13 | kirakira
# Processing Record 21 of Set 13 | terrace
# Processing Record 22 of Set 13 | shakawe
# Processing Record 23 of Set 13 | beloha
# Processing Record 24 of Set 13 | bo phloi
# Processing Record 25 of Set 13 | chara
# Processing Record 26 of Set 13 | basoko
# Processing Record 27 of Set 13 | matara
# Processing Record 28 of Set 13 | kerman
# Processing Record 29 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 13 | san francisco
# Processing Record 31 of Set 13 | yuzhno-kurilsk
# Processing Record 32 of Set 13 | puerto del rosario
# Processing Record 33 of Set 13 | port hedland
# Processing Record 34 of Set 13 | rio grande
# Processing Record 35 of Set 13 | monrovia
# Processing Record 36 of Set 13 | bahia honda
# Processing Record 37 of Set 13 | saldanha
# Processing Record 38 of Set 13 | rio gallegos
# Processing Record 39 of Set 13 | sarangani
# Processing Record 40 of Set 13 | marathon
# Processing Record 41 of Set 13 | grand gaube
# Processing Record 42 of Set 13 | ancud
# Processing Record 43 of Set 13 | kologriv
# Processing Record 44 of Set 13 | sistranda
# Processing Record 45 of Set 13 | mbanza-ngungu
# Processing Record 46 of Set 13 | kondol
# Processing Record 47 of Set 13 | caraquet
# Processing Record 48 of Set 13 | hovd
# Processing Record 49 of Set 13 | kizukuri
# Processing Record 50 of Set 13 | kaseda
# Processing Record 1 of Set 14 | beringovskiy
# Processing Record 2 of Set 14 | todos santos
# Processing Record 3 of Set 14 | rwamagana
# Processing Record 4 of Set 14 | altar
# Processing Record 5 of Set 14 | tiarei
# Processing Record 6 of Set 14 | sur
# Processing Record 7 of Set 14 | buala
# Processing Record 8 of Set 14 | newton
# Processing Record 9 of Set 14 | mus
# Processing Record 10 of Set 14 | beroroha
# Processing Record 11 of Set 14 | ploemeur
# Processing Record 12 of Set 14 | guacimo
# Processing Record 13 of Set 14 | vesyegonsk
# Processing Record 14 of Set 14 | milkovo
# Processing Record 15 of Set 14 | tessalit
# Processing Record 16 of Set 14 | ongandjera
# Processing Record 17 of Set 14 | bac lieu
# Processing Record 18 of Set 14 | pangai
# Processing Record 19 of Set 14 | kosum phisai
# Processing Record 20 of Set 14 | sao joaquim
# Processing Record 21 of Set 14 | marsaxlokk
# Processing Record 22 of Set 14 | macau
# Processing Record 23 of Set 14 | platteville
# Processing Record 24 of Set 14 | el salto
# Processing Record 25 of Set 14 | salinopolis
# Processing Record 26 of Set 14 | alexandria
# Processing Record 27 of Set 14 | mitu
# Processing Record 28 of Set 14 | ugoofaaru
# Processing Record 29 of Set 14 | solnechnyy
# Processing Record 30 of Set 14 | areia branca
# Processing Record 31 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 14 | hauterive
# Processing Record 33 of Set 14 | sipe sipe
# Processing Record 34 of Set 14 | nelson bay
# Processing Record 35 of Set 14 | bulnes
# Processing Record 36 of Set 14 | sinnamary
# Processing Record 37 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 14 | adrar
# Processing Record 39 of Set 14 | lhokseumawe
# Processing Record 40 of Set 14 | bairiki
# Processing Record 41 of Set 14 | linjiang
# Processing Record 42 of Set 14 | cervo
# Processing Record 43 of Set 14 | salalah
# Processing Record 44 of Set 14 | parana
# Processing Record 45 of Set 14 | skibbereen
# Processing Record 46 of Set 14 | noumea
# Processing Record 47 of Set 14 | kashan
# Processing Record 48 of Set 14 | maun
# Processing Record 49 of Set 14 | vung tau
# Processing Record 50 of Set 14 | ridgecrest
# Processing Record 1 of Set 15 | liverpool
# Processing Record 2 of Set 15 | hualmay
# Processing Record 3 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 15 | mackenzie
# Processing Record 5 of Set 15 | vardo
# Processing Record 6 of Set 15 | aranda de duero
# Processing Record 7 of Set 15 | garmsar
# Processing Record 8 of Set 15 | kloulklubed
# Processing Record 9 of Set 15 | shelabolikha
# Processing Record 10 of Set 15 | la orilla
# Processing Record 11 of Set 15 | truckee
# Processing Record 12 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 15 | praxedis guerrero
# Processing Record 14 of Set 15 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 15 of Set 15 | gazanjyk
# Processing Record 16 of Set 15 | eureka
# Processing Record 17 of Set 15 | berezovyy
# Processing Record 18 of Set 15 | salinas
# Processing Record 19 of Set 15 | kaliningrad
# Processing Record 20 of Set 15 | macheng
# Processing Record 21 of Set 15 | tilichiki
# Processing Record 22 of Set 15 | aykhal
# Processing Record 23 of Set 15 | gamba
# Processing Record 24 of Set 15 | tanabe
# Processing Record 25 of Set 15 | jiehu
# Processing Record 26 of Set 15 | sibolga
# Processing Record 27 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 28 of Set 15 | karasjok
# Processing Record 29 of Set 15 | kongolo
# Processing Record 30 of Set 15 | marfino
# Processing Record 31 of Set 15 | akhisar
# Processing Record 32 of Set 15 | talcahuano
# Processing Record 33 of Set 15 | shushtar
# Processing Record 34 of Set 15 | bukama
# Processing Record 35 of Set 15 | la palma del condado
# Processing Record 36 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 15 | kasempa
# Processing Record 38 of Set 15 | chadiza
# Processing Record 39 of Set 15 | belgrade
# Processing Record 40 of Set 15 | spruce grove
# Processing Record 41 of Set 15 | anju
# Processing Record 42 of Set 15 | makaha
# Processing Record 43 of Set 15 | grenville
# Processing Record 44 of Set 15 | gasa
# Processing Record 45 of Set 15 | aswan
# Processing Record 46 of Set 15 | mulege
# Processing Record 47 of Set 15 | garango
# Processing Record 48 of Set 15 | kousseri
# Processing Record 49 of Set 15 | whitehorse
# Processing Record 50 of Set 15 | pomichna
# Processing Record 1 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 16 | wewak
# Processing Record 3 of Set 16 | inuvik
# Processing Record 4 of Set 16 | nipawin
# Processing Record 5 of Set 16 | mogadishu
# Processing Record 6 of Set 16 | ostersund
# Processing Record 7 of Set 16 | imbituba
# Processing Record 8 of Set 16 | pindobacu
# Processing Record 9 of Set 16 | nenjiang
# Processing Record 10 of Set 16 | puerto carreno
# Processing Record 11 of Set 16 | broome
# Processing Record 12 of Set 16 | asayita
# City not found. Skipping...
# Processing Record 13 of Set 16 | jishou
# Processing Record 14 of Set 16 | kruisfontein
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 700

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Mataura      NZ -46.1927  168.8643     65.48        39
# 1  Sao Felix Do Xingu      BR  -6.6447  -51.9950     71.65        97
# 2                Brae      GB  60.3964   -1.3530     44.69        87
# 3            Victoria      HK  22.2855  114.1577     76.03        81
# 4          Butaritari      KI   3.0707  172.7902     81.68        77
# 5            Denpasar      ID  -8.6500  115.2167     85.71        84
# 6          Nikolskoye      RU  59.7035   30.7861     30.78        98
# 7     Belen De Umbria      CO   5.2009  -75.8687     66.85        96
# 8              Tutoia      BR  -2.7619  -42.2744     76.06        87
# 9           Saskylakh      RU  71.9167  114.0833    -17.46        97
#
#    Cloudiness  Wind Speed Current Description
# 0           0        2.55           clear sky
# 1          82        1.21       broken clouds
# 2          88       20.78     overcast clouds
# 3           2       11.01           clear sky
# 4          11       20.47          few clouds
# 5          40        4.61    scattered clouds
# 6         100        3.60     overcast clouds
# 7          90        1.79     overcast clouds
# 8          44        3.44          light rain
# 9          92        2.66     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
